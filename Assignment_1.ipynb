# %% [markdown]
# Name: Praveen Kamal
#
# Reg No: 21BCE0468

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Task 1
#
# Create a pandas dataframe (DataFrame name as 'df') with numpy random values (4 features and 4 observations)

# %%
from numpy import random

# %%
arr = random.randint(10, size=(4, 4))
df = pd.DataFrame(arr)
df
# Out:
#    0  1  2  3
# 0  3  8  2  6
# 1  9  6  0  1
# 2  7  3  9  5
# 3  2  5  1  1

# %% [markdown]
# ## Task 2
#
# Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4'

# %%
df.columns = ["Random value 1", "Random value 2", "Random value 3", "Random value 4"]
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0               3               8               2               6
# 1               9               6               0               1
# 2               7               3               9               5
# 3               2               5               1               1

# %% [markdown]
# ## Task 3
#
# Find the descriptive statistics of the 'df' dataframe.

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         5.250000        5.500000        3.000000        3.250000
# std          3.304038        2.081666        4.082483        2.629956
# min          2.000000        3.000000        0.000000        1.000000
# 25%          2.750000        4.500000        0.750000        1.000000
# 50%          5.000000        5.500000        1.500000        3.000000
# 75%          7.500000        6.500000        3.750000        5.250000
# max          9.000000        8.000000        9.000000        6.000000

# %% [markdown]
# ## Task 4
#
# Check for the null values in 'df' and find the data type of the columns.

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.dtypes
# Out:
# Random value 1    int64
# Random value 2    int64
# Random value 3    int64
# Random value 4    int64
# dtype: object

# %% [markdown]
# ## Task 5
#
# Display the 'Random value 2' & 'Random value 3' columns with location method and index location method.

# %%
df.loc[:, "Random value 2": "Random value 3"]
# Out:
#    Random value 2  Random value 3
# 0               8               2
# 1               6               0
# 2               3               9
# 3               5               1

# %%
df.iloc[:, 1:3]
# Out:
#    Random value 2  Random value 3
# 0               8               2
# 1               6               0
# 2               3               9
# 3               5               1
